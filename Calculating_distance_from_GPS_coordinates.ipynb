# %%
#Importing neccessary libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from numpy.random import randn
from pandas import Series, DataFrame

#Statistics
from scipy import stats


import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import statsmodels.tsa.stattools as smtools
import scipy.stats as scs

# %%
df = pd.read_stata("GPS_saved.dta")
df.head()
# Out:
#    index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong
# 0      0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259
# ...

# %%
from geopy.distance import distance
df['distance_YSU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['YSUlat'], row['YSUlong'])
    ).km),
    axis=1)

# %%
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762
# ...

# %%
from geopy.distance import distance
df['distance_NUACA'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['NUACAlat'], row['NUACAlong'])
    ).km),
    axis=1)

# %%
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198
# ...

# %%
from geopy.distance import distance
df['distance_YSMU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['YSMUlat'], row['YSMUlong'])
    ).km),
    axis=1)

# %%
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198       5.042229
# ...

# %%
from geopy.distance import distance
df['distance_ASPU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['ASPUlat'], row['ASPUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198       5.042229       5.517113
# ...

# %%
from geopy.distance import distance
df['distance_KSCY'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['KSCYlat'], row['KSCYlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198       5.042229       5.517113       4.520046
# ...

# %%
from geopy.distance import distance
df['distance_ANAU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['ANAUlat'], row['ANAUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198       5.042229       5.517113       4.520046       4.943099
# ...

# %%
from geopy.distance import distance
df['distance_NPUA'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['NPUAlat'], row['NPUAlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA
# 0        0        1  Yerevan City  40.208171  44.471346  40.181694  44.526501  40.190353  44.523098  40.188156  44.524502  40.180519  44.525177  40.186493  44.516277  40.191471  44.525162  40.190353  44.523098   40.187153    44.511234  40.184303  44.524742  40.210632  44.503628  40.203358  44.528854  40.785301  43.8423  39.520134  46.345852  40.811401  44.484501  40.356899     45.1259      5.540762        4.830198       5.042229       5.517113       4.520046       4.943099       4.830198
# ...

# %%
from geopy.distance import distance
df['distance_YBSULSS'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['YBSULSSlat'], row['YBSULSSlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS
# ...

# %%
from geopy.distance import distance
df['distance_ASUE'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['ASUElat'], row['ASUElong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE
# ...

# %%
from geopy.distance import distance
df['distance_RAU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['RAUlat'], row['RAUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU
# ...

# %%
from geopy.distance import distance
df['distance_EUA'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['EUAlat'], row['EUAlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA
# ...

# %%
from geopy.distance import distance
df['distance_SSU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['SSUlat'], row['SSUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU
# ...

# %%
from geopy.distance import distance
df['distance_GSU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['GSUlat'], row['GSUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU
# ...

# %%
from geopy.distance import distance
df['distance_VSU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['VSUlat'], row['VSUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU  distance_VSU
# ...

# %%
from geopy.distance import distance
df['distance_GavSTU'] = df.apply(
    (lambda row: distance(
        (row['lati'], row['longi']),
        (row['GavSTUlat'], row['GavSTUlong'])
    ).km),
    axis=1)
df
# Out:
#      index  cluster          city       lati      longi     YSUlat    YSUlong   NUACAlat  NUACAlong    YSMUlat   YSMUlong    ASPUlat   ASPUlong    KSCYlat   KSCYlong    ANAUlat   ANAUlong    NPUAlat   NPUAlong  YBSULSSlat  YBSULSSlong    ASUElat   ASUElong     RAUlat    RAUlong     EUAlat    EUAlong     SSUlat  SSUlong     GSUlat    GSUlong     VSUlat    VSUlong  GavSTUlat  GavSTUlong  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU  distance_VSU  distance_GavSTU
# ...

# %%
df.drop(columns=['lati', 'longi', 'index', 'YSUlat','YSUlong', 'NUACAlat','NUACAlong','YSMUlat','YSMUlong','ASPUlat','ASPUlong','KSCYlat','KSCYlong','ANAUlat','ANAUlong','NPUAlat','NPUAlong','YBSULSSlat','YBSULSSlong','ASUElat','ASUElong','RAUlat','RAUlong','EUAlat','EUAlong','SSUlat','SSUlong','GSUlat','GSUlong', 'VSUlat','VSUlong','GavSTUlat','GavSTUlong'],inplace=True, axis=1)
df.head()
# Out:
#    cluster          city  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU  distance_VSU  distance_GavSTU
# 0        1  Yerevan City      5.540762        4.830198       5.042229       5.517113       4.520046       4.943099       4.830198          4.120933       5.262652      2.761761      4.925159     83.370514    177.647090     66.994628        58.061877
# 1        2  Yerevan City      5.765451        4.962789       5.197648       5.763730       4.756522       5.046767       4.962789          4.390562       5.467332      2.547160      4.821352     82.972028    177.732934     66.272695        57.628368
# ...

# %%
df1 = df.drop([df.columns[0],df.columns[1]], axis='columns') 
df1
# Out:
#      distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU  distance_VSU  distance_GavSTU
# 0        5.540762        4.830198       5.042229       5.517113       4.520046       4.943099       4.830198          4.120933       5.262652      2.761761      4.925159     83.370514    177.647090     66.994628        58.061877
# 1        5.765451        4.962789       5.197648       5.763730       4.756522       5.046767       4.962789          4.390562       5.467332      2.547160      4.821352     82.972028    177.732934     66.272695        57.628368
# 2        6.837379        6.249578       6.432848       6.785254       5.831106       6.388208       6.249578          5.404548       6.591322      4.407566      6.518803     82.599500    178.983810     67.361613        59.705016
# ...

# %%
df['distance'] = df1.min(axis=1) 
df
# Out:
#      cluster          city  distance_YSU  distance_NUACA  distance_YSMU  distance_ASPU  distance_KSCY  distance_ANAU  distance_NPUA  distance_YBSULSS  distance_ASUE  distance_RAU  distance_EUA  distance_SSU  distance_GSU  distance_VSU  distance_GavSTU   distance
# 0          1  Yerevan City      5.540762        4.830198       5.042229       5.517113       4.520046       4.943099       4.830198          4.120933       5.262652      2.761761      4.925159     83.370514    177.647090     66.994628        58.061877   2.761761
# 1          2  Yerevan City      5.765451        4.962789       5.197648       5.763730       4.756522       5.046767       4.962789          4.390562       5.467332      2.547160      4.821352     82.972028    177.732934     66.272695        57.628368   2.547160
# ...

# %%
df.drop(columns=['distance_YSU', 'distance_NUACA', 'distance_YSMU', 'distance_ASPU','distance_KSCY', 'distance_ANAU','distance_NPUA','distance_YBSULSS','distance_ASUE','distance_RAU','distance_EUA','distance_SSU','distance_GSU','distance_VSU','distance_GavSTU'],inplace=True, axis=1)
df.head()
# Out:
#    cluster          city  distance
# 0        1  Yerevan City  2.761761
# 1        2  Yerevan City  2.547160
# 2        3  Yerevan City  4.407566
# 3        4  Yerevan City  1.984462
# 4        5  Yerevan City  2.229477

# %%
df.to_stata('GPS_distance.dta')
